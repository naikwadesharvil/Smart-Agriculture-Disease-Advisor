# %%
# 🌿 Smart Agriculture Disease Advisor

## Model Evaluation

### Objective : The objective of this notebook is to evaluate the performance of the trained CNN model using the validation dataset. The notebook includes model loading, prediction generation, evaluation metrics, confusion matrix visualization, classification report, and sample predictions.

### Goals

#- Load the trained CNN model
#- Evaluate model performance
#- Generate predictions
#- Display confusion matrix
#- Generate classification report
#- Visualize sample predictions

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import classification_report, confusion_matrix

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !kaggle datasets download -d mohitsingh1804/plantvillage
# !unzip -oq plantvillage.zip -d /content/plantvillage
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/mohitsingh1804/plantvillage
# License(s): GPL-2.0
# plantvillage.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
IMG_SIZE = (128,128)
BATCH_SIZE = 16

val_ds = tf.keras.utils.image_dataset_from_directory(
    "/content/plantvillage/PlantVillage/val",
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=False
)
# Out:
# Found 10861 files belonging to 38 classes.

# %%
normalization_layer = tf.keras.layers.Rescaling(1./255)

val_ds = val_ds.map(lambda x, y: (normalization_layer(x), y))

# %%
model = tf.keras.models.load_model(
    "/content/drive/MyDrive/plant_disease_cnn.keras",
    compile=False
)

print("✅ Model Loaded Successfully")
# Out:
# ✅ Model Loaded Successfully

# %%
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

# %%
loss, accuracy = model.evaluate(val_ds)

print(f"Validation Loss: {loss:.4f}")
print(f"Validation Accuracy: {accuracy:.4f}")
# Out:
# 679/679 ━━━━━━━━━━━━━━━━━━━━ 108s 157ms/step - accuracy: 0.9252 - loss: 0.2368
# Validation Loss: 0.2368
# Validation Accuracy: 0.9252
